# %%
from datetime import datetime, timedelta

def date_time(d):
  date = "23 April, 2020"
  new_date = datetime.strptime(date, "%d %B, %Y")
  
  print(new_date + timedelta(days = d))
  

d = 5
date_time(d)
# Out:
# 2020-04-28 00:00:00

# %%
def funct(a):
  sentence = 'Hello world!'
  print(sentence[::a])


funct(3)
# Out:
# Hlwl

# %%
def funct(a):
  b = ['Hello','World','1','2','3','4', 5, 6, 7]
  print(b[0::a])

funct(2)
# Out:
# ['Hello', '1', '3', 5, 7]

# %%
def funct(a):
  f = ('apple',)
  print(f+a)


funct(('orange','apple','apple'))
# Out:
# ('apple', 'orange', 'apple', 'apple')

# %%
def funct(a):
  (b, c, d) = a 
  (x, y) = b 

  print("Hi {0} {1}".format(x, y))
  print("You answered {1} and {0}".format(c,d))


funct((["Jenna","Smith"],"star","orange"))
# Out:
# Hi Jenna Smith
# You answered orange and star

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
def funct(a):
  with open('/content/drive/My Drive/Colab Notebooks/abc.txt', 'a') as myfile:
    myfile.write(str(a*a))
    myfile.write(str(a%a))

funct(3)

# %%
def read_file2(name):
  with open(name, "r") as myfile:
    print(myfile.read())

# %%
read_file2("/content/drive/My Drive/Colab Notebooks/abc.txt")
# Out:
# 0690

# %%
def funct():
  file = open('/content/drive/My Drive/Colab Notebooks/abc.txt')
  a = []
  while True:
    line = file.readline()
    if len(line) == '\n':
      a.append('new')
    else:
      a.append(line)
  file.close()

  print(a)

# %%
a = ['new','new','hello','world']
print(a)
# Out:
# ['new', 'new', 'hello', 'world']

# %%
def funct(a, b, c):
  print("Hi %s %s" %(a, b))
  print("Your data is: %s " %c[1])
  print("Your data is: %s " %c[0])
  print("Your data is: %s " %c[2])




funct('Joe','Smith',[17, 54, 39])
# Out:
# Hi Joe Smith
# Your data is: 54
# Your data is: 17
# Your data is: 39

# %%
def funct(a):
  b = [1, 2, 3, 1, 4, 5, 2, 2, 4, 3]
  c = 0
  d = 0
  for i in b:
    if i == a:
      b = sorted(b)
    else:
      if c == 0:
        c = b 
      elif d is not c:
        d = b
      continue

  print([a]+b+c+d)

  
funct(1)
# Out:
# [1, 1, 1, 2, 2, 2, 3, 3, 4, 4, 5, 1, 1, 2, 2, 2, 3, 3, 4, 4, 5, 1, 1, 2, 2, 2, 3, 3, 4, 4, 5]

# %%
def funct(a):
  b = [21, 14, 21, 14, 32, 42, 23, 42]
  c = 10
  d = 10
  for i in b:
    if i == a:
      b = sorted(b)
    else:
      try:
        if c > 0:
          c = b 
        elif d is not c:
          d = b
      except:
        c = b
        d = b

  print(d+b+c+[a])

  
funct(21)
# Out:
# [14, 14, 21, 21, 23, 32, 42, 42, 14, 14, 21, 21, 23, 32, 42, 42, 14, 14, 21, 21, 23, 32, 42, 42, 21]

# %%
a = int(input())

if a % 2:
  print("1")

elif not a % 2:
  print("2")

else:
  print("3")
# Out:
# F
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0e524c212823> in <module>()
# ----> 1 a = int(input())
#       2
#       3 if a % 2:
#       4   print("1")
#       5
#
# ValueError: invalid literal for int() with base 10: 'F'

# %%
def funct(a, b):
  c = ""
  for i in range(b):
    c = c + a
  return c

print(funct('123',3))
print(funct('abc',2))
# Out:
# 123123123
# abcabc

# %%
a = [452, 234, 876, 383, 12, 54, 78, 72, 27, 527, 417]

for i in a:
  if i > 500:
    print(i)
    break
  elif i % 2 == 0:
    print(i)
# Out:
# 452
# 234
# 876

# %%
def funct(a, b):
  c = a + b
  if c in range(20,30):
    return 25
  else:
    return c

print(funct(20,6))
print(funct(15,6))
print(funct(10,6))
# Out:
# 25
# 25
# 16

# %%
import random
def funct():
  a = 0
  b = False
  for x in range(2):
      a=a+random.randint(1,6)

  if 2 <= a <= 4 or 10 <= a <= 12:
      c = random.randint(1,100)
      if c >= 75:
          b = True

  return(a,b)

funct()
# Out:
# (11, False)

# %%
import random
c = {
  'a': '1',
  'b': '2',
  'c': '3'
}

def funct():
  a=random.randint(1,6)
  b=False
  if a >=5:
    b = True

  if b == True:
    print("True")
  else:
    if 5 <= a <= 6:
      print(c['a'])
    elif a == 2:
      print(c['b'])
    else:
      print(c['c'])

funct()
# Out:
# 3

# %%
for i in string.ascii_uppercase:
  with open(i + ".txt", "w") as f:
    f.writelines(i)

# %%
with open('a.txt') as a:
  with open('b.txt') as b:
    for c in a:
      for d in b:
        print(c+d)

# %%
print(123)
print('asd')
print(123)
# Out:
# 123
# asd
# 123

# %%
print(345)
print('qwe')
print(345)
print('qwe')
print(345)
print('qwe')
# Out:
# 345
# qwe
# 345
# qwe
# 345
# qwe

# %%
import csv
with open('a.csv', 'w+') as csvfile:
  a = ['First','Last','Department']
  b = csv.writer(csvfile, fieldnames=a)
  b.writerow(['George','Smith','BIO'])
  b.writerow(['Diana','Cho','EECS'])

with open('a.csv','r') as csvfile:
  c = csv.DictReader(csvfile)
  for i in c:
    print(i['First','Department'])

# %%
import csv
with open('a.csv', 'r') as csvfile:
   a = csv.DictReader(csvfile, delimiter='|')
   for b in a:
       print(b['First']+b['Last']+"said"+b['Text'])

# %%
print('Mary Smith said have a sunny day')
# Out:
# Mary Smith said have a sunny day
