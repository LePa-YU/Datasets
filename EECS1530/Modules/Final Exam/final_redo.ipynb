# %%
def a_function (x,y):
  return x*y
  c=3
  return c
a = a_function (10,5)
print(c*a)

# %%
def a_function (x,y):
  return

# %%
print("You are {0}, and you're {1:>10} years old".format('Jo',34))
